# %% [markdown]
# import numpy as np
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# df=pd.read_csv("C:/Users/Funmi/AppData/Local/Temp/95d49d96-1f5d-4703-af97-d06d271a49ec_archive (20).zip.9ec/diabetes.csv")
# print(df.to_string())

# %%
print(df.head(10))
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
print(df.tail(10))
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
num=[]
cat=[]
for column in df.columns:
    if df[column].nunique()>10:
        num.append(column)
    else:
        cat.append(column)

# %%
num
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
cat
# Out:
# ['Outcome']

# %%
df["Outcome"].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# This shows that the outcome of people with diabetics are less(268) while those that are non diabetics are much(500).

# %%
df["Outcome"].value_counts().plot(kind="bar",color="red")
# Out:
# <Axes: xlabel='Outcome'>

# %%
sns.countplot(x="Outcome",data=df)
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.value_counts()
# Out:
# Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI   DiabetesPedigreeFunction  Age  Outcome
# 0            57       60             0              0        21.7  0.735                     67   0          1
#              67       76             0              0        45.3  0.194                     46   0          1
# 5            103      108            37             0        39.2  0.305                     65   0          1
#              104      74             0              0        28.8  0.153                     48   0          1
#              105      72             29             325      36.9  0.159                     28   0          1
#                                                                                                             ..
# 2            84       50             23             76       30.4  0.968                     21   0          1
# ...

# %%
df["BloodPressure"].skew()
# Out:
# -1.8436079833551302

# %%
df["Glucose"].skew()
# Out:
# 0.17375350179188992

# %%
df.hist(figsize=(18,18))
plt.show()

# %%
df.groupby("Outcome").mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
pd.crosstab(df.head(10)["Pregnancies"],df.head(10)["Outcome"])
# Out:
# Outcome      0  1
# Pregnancies
# 0            0  1
# 1            2  0
# 2            0  1
# 3            0  1
# 5            1  0
# 6            0  1
# 8            0  2
# 10           1  0

# %%
sns.heatmap(pd.crosstab(df.head(10)["Outcome"],df.head(10)["Pregnancies"]))
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Outcome'>

# %%
preg=df["Outcome"]
bld=df["BloodPressure"]
sns.barplot(x=preg,y=bld,data=df)
# Out:
# <Axes: xlabel='Outcome', ylabel='BloodPressure'>

# %%
preg=df["Outcome"]
bld=df["Pregnancies"]
sns.barplot(x=preg,y=bld,data=df)
# Out:
# <Axes: xlabel='Outcome', ylabel='Pregnancies'>

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
np.percentile(df["Pregnancies"],75)
# Out:
# 6.0
